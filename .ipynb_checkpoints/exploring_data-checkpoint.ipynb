# %%
import pandas as pd
import numpy as np
import scipy as sp
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/clean_stop_data.csv')

# %%
df.head()
# Out:
#      year  month   day  hour citizen_race citizen_gender  citizen_age  \
# 0  2015.0    1.0   1.0  22.0        white           male         53.0
# 1  2015.0    1.0   2.0  16.0        white           male          NaN
# 2  2015.0    1.0   2.0  20.0        Black         female          NaN
# 3  2015.0    1.0   2.0  20.0        Black           male         24.0
# 4  2015.0    1.0  11.0  17.0        Black           male         24.0
#
#   officer_race officer_gender      division    beat  \
# 0        Asian         female  6TH DIVISION  BEAT 1
# 1        Asian         female  6TH DIVISION  BEAT 5
# 2        Asian         female  6TH DIVISION  BEAT 5
# 3        Asian         female  6TH DIVISION  BEAT 5
# 4        Asian         female  6TH DIVISION  BEAT 2
#
#                                            violation  frisked  searched  \
# 0  FAIL OF NON-OWNER/OPER TO MAINTAIN REQ INS/SEC...        0         0
# 1                                                NaN        0         0
# ...

# %%
overview = df.groupby('citizen_race').aggregate(np.sum)[['frisked', 'searched', 'citation_issued']]

# %%
stops = pd.Series(df.citizen_race.value_counts())
overview['stops'] = stops
overview = overview[['stops', 'searched', 'frisked', 'citation_issued']]
overview['pop'] = pd.Series({'Black': 171781, 'white': 546872, 'Native American': 1302, 'Asian': 22829, 'Latino': 45355, 'Middle Eastern': 'NaN', 'Unknown': 'Nan'})

# %%
overview['% frisked'] = overview['frisked'] / overview['stops']
overview['% searched'] = overview['searched'] / overview['stops']
overview['% cited'] = overview['citation_issued'] / overview['stops']

# %%
overview
# Out:
#                  stops  searched  frisked  citation_issued     pop  % frisked  \
# citizen_race
# Asian              411        25        0               60   22829   0.000000
# Black            34943      3125        9            23494  171781   0.000258
# Latino            4843       254        0             3536   45355   0.000000
# Middle Eastern     444        38        0               57     NaN   0.000000
# Native American     65         2        0               50    1302   0.000000
# Unknown              2         0        0                2     Nan   0.000000
# white            69340      3435        7            54073  546872   0.000101
#
#                  % searched   % cited
# citizen_race
# Asian              0.060827  0.145985
# Black              0.089431  0.672352
# Latino             0.052447  0.730126
# Middle Eastern     0.085586  0.128378
# Native American    0.030769  0.769231
# Unknown            0.000000  1.000000
# white              0.049539  0.779824

# %%
overview_3 = df.groupby(['officer_race', 'citizen_race']).aggregate(np.sum)[['frisked', 'searched', 'citation_issued']]

# %%
overview_3['stops'] = df.groupby(['officer_race', 'citizen_race'])['year'].count()

# %%
overview_3['% frisked'] = overview_3['frisked'] / overview_3['stops']
overview_3['% searched'] = overview_3['searched'] / overview_3['stops']
overview_3['% cited'] = overview_3['citation_issued'] / overview_3['stops']

# %%
overview_3
# Out:
#                               frisked  searched  citation_issued  stops  \
# officer_race citizen_race
# Asian        Asian                  0         0                0      7
#              Black                  0        77              255    565
#              Latino                 0         8               37     74
#              Middle Eastern         0         0                0      2
#              white                  0        74              330    764
# Black        Asian                  0         1                3     46
#              Black                  2       383             5124   6733
#              Latino                 0        13              686    800
#              Middle Eastern         0         4                9     84
#              Native American        0         0               13     16
#              Unknown                0         0                1      1
#              white                  0       399            11919  13663
# ...

# %%
# https://stackoverflow.com/questions/24179284/accessing-hierarchical-columns-in-pandas-after-groupby

# %%
Asian_pct_searched = (overview_3.loc['Asian', '% searched'] * 100).round(2)
Black_pct_searched = (overview_3.loc['Black', '% searched'] * 100).round(2)
Latino_pct_searched = (overview_3.loc['Latino', '% searched'] * 100).round(2)
white_pct_searched = (overview_3.loc['Latino', '% searched'] * 100).round(2)

# %%
Asian_pct_searched[2]
# Out:
# 10.81

# %%
labels = ['Asian officers', 'Black officers', 'Latino officers', 'white officers']
Asian_pct_searched[0,1,2]
Black_pct_searched[0,1,2]
Latino_pct_searched[0,1,2]
white_pct_searched[0,1,2]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/4, Asian_pct_searched, width, label='Asian')
rects2 = ax.bar(x + width/4, Black_pct_searched, width, label='Black')
rects3 = ax.bar(x + width/4, Latino_pct_searched, width, label='Latino')
rects4 = ax.bar(x + width/4, white_pct_searched, width, label='white')


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Percent')
ax.set_title('Percent searched by race')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-134-d0ffbc74451e> in <module>
#       1 labels = ['Asian officers', 'Black officers', 'Latino officers', 'white officers']
# ----> 2 Asian_pct_searched[0,1,2]
#       3 Black_pct_searched[0,1,2]
#       4 Latino_pct_searched[0,1,2]
#       5 white_pct_searched[0,1,2]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     904             return self._get_values(key)
#     905
# --> 906         return self._get_with(key)
#     907
#     908     def _get_with(self, key):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in _get_with(self, key)
#     919             )
#     920         elif isinstance(key, tuple):
# --> 921             return self._get_values_tuple(key)
#     922
#     923         elif not is_list_like(key):
#
# ...
